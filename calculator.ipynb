# %%
import tkinter as tk
import math

root = tk.Tk()  # Main box window
root.title("modern Calculator")  # Title shown at the title bar
root.resizable(0,0)  # disabling the resizeing of the window
root.configure(bg="#6498ba")

# Creating an entry field:
d = tk.Entry(root,
             width=35,
             bg='#8c895e',
             fg='#dbd8d3',
             borderwidth=5,
             justify='right',
             font='Calibri 15')
d.grid(row=0, column=0, columnspan=3, padx=12, pady=12)


def buttonClick(num):  # function for clicking
    temp = d.get(
    )  # temporary varibale to store the current input in the screen
    d.delete(0, tk.END)  # clearing the screen from index 0 to END
    d.insert(0, temp + num)  # inserting the incoming number input


def buttonClear():  # function for clearing
    d.delete(0, tk.END)
    



def buttonGet(
        oper
):  # function for storing the first input and printing '+, -, /, *'
    global num1, math  # global variable num1 and math to use in function buttonEqual()
    num1 = d.get()  # getting first number
    math = oper  # oper varaible is the type of operation being performed
    d.insert(tk.END, math)
    try:
        num1 = float(num1)  # converting the number to float type
    except ValueError:  # in case there is a character other than numerals, clear the screen
        buttonClear()
        

        


def buttonEqual():  # function for printing the sum
    inp = d.get()  # getting the inserted input
    num2 = float(inp[inp.index(math) + 1:])  # getting the second number
    d.delete(0, tk.END)
    if math == '+':  # Addition
        d.insert(0, str(num1 + num2))
    elif math == '-':  # Subtraction
        d.insert(0, str(num1 - num2))
    elif math == 'x':  # Multiplication
        d.insert(0, str(num1 * num2))
    elif math == '^':  # power
        d.insert(0, str(num1 ** num2))
   
    elif math == '%':  # percentage
        d.insert(0, str(num1 % num2))
    elif math == '/':  # Division
        try:
            d.insert(0, str(num1 / num2))
        except ZeroDivisionError:
            # in case there is a zero in the denominator, answer is undefined
            e.insert(0, 'Undefined')

def buttonback():
    inp = len(d.get())
    d.delete(inp - 1)
    

# Defining Buttons:
c1 = tk.Button(root,
               text='1',
               padx=40,
               pady=10,
               command=lambda: buttonClick('1'),
               font='Calibri 12',
               bg="#c0dfee",activebackground="#d9423e") # for color changing
c2 = tk.Button(root,
               text='2',
               padx=40,
               pady=10,
               command=lambda: buttonClick('2'),
               font='Calibri 12',
               bg="#c0dfee",activebackground="#d9423e") # for color changing
c3 = tk.Button(root,
               text='3',
               padx=40,
               pady=10,
               command=lambda: buttonClick('3'),
               font='Calibri 12',
               bg="#c0dfee",activebackground="#d9423e") # for color changing
c4 = tk.Button(root,
               text='4',
               padx=40,
               pady=10,
               command=lambda: buttonClick('4'),
               font='Calibri 12',
               bg="#c0dfee",activebackground="#d9423e") # for color changing
c5 = tk.Button(root,
               text='5',
               padx=40,
               pady=10,
               command=lambda: buttonClick('5'),
               font='Calibri 12',
               bg="#c0dfee",activebackground="#d9423e") # for color changing
c6 = tk.Button(root,
               text='6',
               padx=40,
               pady=10,
               command=lambda: buttonClick('6'),
               font='Calibri 12',
               bg="#c0dfee",activebackground="#d9423e") # for color changing
c7 = tk.Button(root,
               text='7',
               padx=40,
               pady=10,
               command=lambda: buttonClick('7'),
               font='Calibri 12',
               bg="#c0dfee",activebackground="#d9423e") # for color changing
c8 = tk.Button(root,
               text='8',
               padx=40,
               pady=10,
               command=lambda: buttonClick('8'),
               font='Calibri 12',
               bg="#c0dfee",activebackground="#d9423e") # for color changing
c9 = tk.Button(root,
               text='9',
               padx=40,
               pady=10,
               command=lambda: buttonClick('9'),
               font='Calibri 12',
               bg="#c0dfee",activebackground="#d9423e") # for color changing
c0 = tk.Button(root,
               text='0',
               padx=40,
               pady=10,
               command=lambda: buttonClick('0'),
               font='Calibri 12',
               bg="#c0dfee",activebackground="#d9423e") # for color changing
c00 = tk.Button(root,
               text='00',
               padx=37,
               pady=10,
               command=lambda: buttonClick('00'),
               font='Calibri 12',
               bg="#c0dfee",activebackground="#d9423e") # for color changing
cdot = tk.Button(root,
                 text='.',
                 padx=41,
                 pady=10,
                 command=lambda: buttonClick('.'),
                 font='Calibri 12',
                 bg="#c0dfee",activebackground="#d9423e") # for color changing


cadd = tk.Button(root,
                 text='+',
                 padx=29,
                 pady=10,
                 command=lambda: buttonGet('+'),
                 font='Calibri 12',
                 bg="#c0dfee",activebackground="#d9423e") # for color changing
csub = tk.Button(root,
                 text='-',
                 padx=30,
                 pady=10,
                 command=lambda: buttonGet('-'),
                 font='Calibri 12',
                 bg="#c0dfee",activebackground="#d9423e") # for color changing
cmul = tk.Button(root,
                 text='x',
                 padx=30,
                 pady=10,
                 command=lambda: buttonGet('x'),
                 font='Calibri 12',
                 bg="#c0dfee",activebackground="#d9423e") # for color changing
cdiv = tk.Button(root,
                 text='/',
                 padx=30.5,
                 pady=10,
                 command=lambda: buttonGet('/'),
                 font='Calibri 12',
                 bg="#c0dfee",activebackground="#d9423e") # for color changing



cpow = tk.Button(root,
                 text='^',
                 padx=30,
                 pady=10,
                 command=lambda: buttonGet('^'),
                 font='Calibri 12',
                 bg="#c0dfee",activebackground="#d9423e") # for color changing
cper = tk.Button(root,
                 text='%',
                 padx=30,
                 pady=10,
                 command=lambda: buttonGet('%'),
                 font='Calibri 12',
                 bg="#c0dfee",activebackground="#d9423e") # for color changing

cclear = tk.Button(root,
                   text='AC',
                   padx=20,
                   pady=10,
                   command=buttonClear,
                   font='Calibri 12',
                   bg="#c0dfee",activebackground="#d9423e") # for color changing
cequal = tk.Button(root,
                   text='=',
                   padx=30,
                   pady=30,
                   command=buttonEqual,
                   font='Calibri 12',
                   bg="#d9423e",activebackground="#cb1d1d") # for color changing
cback = tk.Button(root,
                  text='<-',
                  padx=30,
                  pady=10,
                  command=buttonback,
                  font='Calibri 12',
                  bg="#c0dfee",activebackground="#d9423e") # for color changing

# Putting the buttons on the screen:
cclear.grid(row=0, column=3)
cback.grid(row=0, column=4)

c7.grid(row=1, column=0)
c8.grid(row=1, column=1)
c9.grid(row=1, column=2)
cdiv.grid(row=1, column=3)
cpow.grid(row=1, column=4)


c4.grid(row=2, column=0)
c5.grid(row=2, column=1)
c6.grid(row=2, column=2)
cmul.grid(row=2, column=3)
cper.grid(row=2, column=4)


c1.grid(row=3, column=0)
c2.grid(row=3, column=1)
c3.grid(row=3, column=2)
cadd.grid(row=3, column=3)

c00.grid(row=4, column=0)
c0.grid(row=4, column=1)
cdot.grid(row=4, column=2)
csub.grid(row=4, column=3)
cequal.grid(row=3, column=4,rowspan=2)



# Looping the window:
root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\patil\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\patil\AppData\Local\Temp\ipykernel_29048\2237718651.py", line 51, in buttonEqual
#     num2 = float(inp[inp.index(math) + 1:])  # getting the second number
# TypeError: must be str, not module
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\patil\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\patil\AppData\Local\Temp\ipykernel_29048\2237718651.py", line 51, in buttonEqual
#     num2 = float(inp[inp.index(math) + 1:])  # getting the second number
# TypeError: must be str, not module
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\patil\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
# ...
